# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import fastai
from fastai.vision import *

# %%
bs = 16

# %%
path = untar_data(URLs.); path

# %%
path =  Path("/home/anukoolpurohit/Documents/AnukoolPurohit/Datasets/dogscats")

# %%
tfms = get_transforms()

# %%
data = ImageDataBunch.from_folder(path,train='train', valid="valid",
                                  ds_tfms=tfms, size=224, bs=bs)
data.normalize(imagenet_stats)
# Out:
# ImageDataBunch;
#
# Train: LabelList
# y: CategoryList (23000 items)
# [Category cats, Category cats, Category cats, Category cats, Category cats]...
# Path: /home/anukoolpurohit/Documents/AnukoolPurohit/Datasets/dogscats
# x: ImageItemList (23000 items)
# [Image (3, 132, 200), Image (3, 375, 499), Image (3, 374, 500), Image (3, 232, 350), Image (3, 500, 374)]...
# Path: /home/anukoolpurohit/Documents/AnukoolPurohit/Datasets/dogscats;
#
# Valid: LabelList
# y: CategoryList (2000 items)
# [Category cats, Category cats, Category cats, Category cats, Category cats]...
# Path: /home/anukoolpurohit/Documents/AnukoolPurohit/Datasets/dogscats
# x: ImageItemList (2000 items)
# [Image (3, 374, 500), Image (3, 360, 479), Image (3, 499, 428), Image (3, 449, 500), Image (3, 374, 500)]...
# Path: /home/anukoolpurohit/Documents/AnukoolPurohit/Datasets/dogscats;
#
# Test: None

# %%
data.show_batch(rows=3)

# %%
arch = models.resnet34
learn = create_cnn(data, arch, metrics=accuracy)

# %%
learn.fit_one_cycle(5)
# Out:
# Total time: 07:10 <p><table style='width:300px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>accuracy</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>0.095516</th>
#     <th>0.049140</th>
#     <th>0.984000</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>0.064036</th>
#     <th>0.026178</th>
#     <th>0.991500</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>0.049364</th>
#     <th>0.027280</th>
#     <th>0.990000</th>
#   </tr>
#   <tr>
#     <th>4</th>
#     <th>0.034183</th>
#     <th>0.025332</th>
#     <th>0.992000</th>
#   </tr>
#   <tr>
#     <th>5</th>
#     <th>0.039130</th>
#     <th>0.023498</th>
#     <th>0.991500</th>
#   </tr>
# </table>

# %%
learn.recorder.plot_losses()
